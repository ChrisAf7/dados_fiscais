# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\chris\OneDrive\Documentos\MMRoldão\rgf_coleta\outputs\rgf_pernambuco_2019_2024.csv")

# %%
df_sim=pd.read_csv(r"C:\Users\chris\OneDrive\Documentos\MMRoldão\rgf_coleta\outputs\municipios_simplificados_ceara_2019_2024.csv")

# %%
len(df["instituicao"].unique())
# Out:
# 175

# %%
len(df[df["exercicio"]==2024]["instituicao"].unique())
# Out:
# 168

# %%
df["instituicao"]
# Out:
# 0             Prefeitura Municipal de Abaiara - CE
# 1             Prefeitura Municipal de Abaiara - CE
# 2             Prefeitura Municipal de Abaiara - CE
# 3             Prefeitura Municipal de Abaiara - CE
# 4             Prefeitura Municipal de Abaiara - CE
#                            ...
# 5882    Prefeitura Municipal de Várzea Alegre - CE
# 5883    Prefeitura Municipal de Várzea Alegre - CE
# 5884    Prefeitura Municipal de Várzea Alegre - CE
# 5885    Prefeitura Municipal de Várzea Alegre - CE
# 5886    Prefeitura Municipal de Várzea Alegre - CE
# Name: instituicao, Length: 5887, dtype: object

# %%
df_sim.shape[0]+len(df["instituicao"].unique())
# Out:
# 218

# %%
df
# Out:
#       exercicio                             instituicao  uf  \
# 0          2019  Prefeitura Municipal de Alagoinha - PE  PE
# 1          2019  Prefeitura Municipal de Alagoinha - PE  PE
# 2          2019  Prefeitura Municipal de Alagoinha - PE  PE
# 3          2019    Prefeitura Municipal de Aliança - PE  PE
# 4          2019    Prefeitura Municipal de Aliança - PE  PE
# ...         ...                                     ...  ..
# 5604       2024      Prefeitura Municipal de Xexéu - PE  PE
# 5605       2024      Prefeitura Municipal de Xexéu - PE  PE
# 5606       2024      Prefeitura Municipal de Xexéu - PE  PE
# 5607       2024      Prefeitura Municipal de Xexéu - PE  PE
# 5608       2024      Prefeitura Municipal de Xexéu - PE  PE
#
#                                                   conta        valor
# 0                                    DÍVIDA CONSOLIDADA   4451408.86
# 1                        Disponibilidade de Caixa Bruta   1979127.10
# ...

# %%
anos=[2024,2025]
periodos=(3,2,1)

tentativas = [
    (ano, periodo)
    for ano in sorted(anos, reverse=True)
    for periodo in periodos
    ]

# %%
tentativas
# Out:
# [(2025, 3), (2025, 2), (2025, 1), (2024, 3), (2024, 2), (2024, 1)]

# %%
dicionario={
    "ano":2012,
    "periodo":3,
    "vale_quem_tem":"lulu"
}

# %%
dicionario.get("ano")
# Out:
# 2012

# %%
if isinstance(dicionario,list):
    print("Hello World")

# %%
df=pd.read_csv(r"C:\Users\chris\OneDrive\Documentos\MMRoldão\rgf_coleta\debug_tabelas.csv")

# %%
df["items"].loc[0]
# Out:
# "[{'exercicio': 2025, 'periodo': 1, 'periodicidade': 'Q', 'instituicao': 'Prefeitura Municipal de Teresina - PI', 'cod_ibge': 2211001, 'uf': 'PI', 'co_poder': 'E', 'populacao': 868523, 'anexo': 'RGF-Anexo 02', 'esfera': 'M', 'rotulo': 'Padrão', 'coluna': 'SALDO DO EXERCÍCIO ANTERIOR', 'cod_conta': 'DividaConsolidada', 'conta': 'DÍVIDA CONSOLIDADA - DC (I)', 'valor': 1735489491.29}, {'exercicio': 2025, 'periodo': 1, 'periodicidade': 'Q', 'instituicao': 'Prefeitura Municipal de Teresina - PI', 'cod_ibge': 2211001, 'uf': 'PI', 'co_poder': 'E', 'populacao': 868523, 'anexo': 'RGF-Anexo 02', 'esfera': 'M', 'rotulo': 'Padrão', 'coluna': 'Até o 1º Quadrimestre', 'cod_conta': 'DividaConsolidada', 'conta': 'DÍVIDA CONSOLIDADA - DC (I)', 'valor': 1539118015.17}, {'exercicio': 2025, 'periodo': 1, 'periodicidade': 'Q', 'instituicao': 'Prefeitura Municipal de Teresina - PI', 'cod_ibge': 2211001, 'uf': 'PI', 'co_poder': 'E', 'populacao': 868523, 'anexo': 'RGF-Anexo 02', 'esfera': 'M', 'rotulo': 'Pa
# ...
